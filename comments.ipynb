# %% [markdown]
# ## Product comments
#
# Product comments are tallied at 12 days, need to know if it's necessary to consider changes over time.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

comments = pd.read_csv('data/JData_Comment.csv')

comment_group = comments.groupby('sku_id')

# %%
num_diff = comment_group['comment_num'].max() - comment_group['comment_num'].min()
bad_diff = comment_group['has_bad_comment'].max() - comment_group['has_bad_comment'].min()
rate_diff = comment_group['bad_comment_rate'].max() - comment_group['bad_comment_rate'].min()

# %%
plt.plot(num_diff, 'b.')
plt.show()

# %%
plt.plot(bad_diff, 'r.')
plt.show()

# %%
plt.plot(rate_diff * 1000, 'g.')
plt.show()

# %%
dates = np.unique(comments['dt'])
comment_time = comments[comments['dt'] == dates[0]]
comment_time.columns = ['dt', 'sku_id']
for date in dates[1:]:
